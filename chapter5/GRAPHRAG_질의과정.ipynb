# %% [markdown]
# # **환경설정**

# %%
# !pip install graphrag

# 구글 드라이브 마운트
from google.colab import drive
drive.mount('/content/drive')

# %%
# 작업 디렉터리 변경
import os
os.chdir('/content/drive/My Drive/working_directory')

# 현재 작업 디렉터리 확인
print("현재 작업 디렉터리:")
# !pwd

# %% [markdown]
# # **포괄적인 질문 - 글로벌 검색**

# %%
# !graphrag query \
--root ./ \
--method global \
--query "채권의 전환성 개념이 각 챕터들에서 어떻게 소개되어 있나요?"

# %% [markdown]
# # **포괄적인 질문 - 로컬 검색**

# %%
# !graphrag query \
--root ./ \
--method local \
--query "채권의 전환성 개념이 각 챕터들에서 어떻게 소개되어 있나요?"

# %% [markdown]
# # **세부적인 질문 - 글로벌 검색**

# %%
# !graphrag query \
--root ./ \
--method global \
--query "산업채권 평가 시 순유동자산(Net Quick Assets)을 어떻게 분석해야 하나요?"

# %% [markdown]
# # **세부적인 질문 - 로컬 검색**

# %%
# !graphrag query \
--root ./ \
--method local \
--query "산업채권 평가 시 순유동자산(Net Quick Assets)을 어떻게 분석해야 하나요?"
